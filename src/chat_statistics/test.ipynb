# %%
import json
from hazm import word_tokenize, Normalizer
from collections import Counter
from wordcloud import WordCloud
import arabic_reshaper
from bidi.algorithm import get_display

# %%
with open('../Data/SM_Group.json') as f:
    data = json.load(f)

# %%
stop_words = open('StopWords.txt').readlines()
stop_words = list(map(str.strip, stop_words))
stop_words = list(map(normalizer.normalize, stop_words))

# %%
text_content = ""
for msg in data['messages']:
    if isinstance(msg['text'], str):
        tokens = word_tokenize(msg['text'])
        tokens = list(filter(lambda word: word not in stop_words, tokens))
        text_content += f" {' '.join(tokens)}"

# %%
Counter(word_tokenize(text_content)).most_common()

# %%
normalizer = Normalizer()
text_content = normalizer.normalize(text_content) 
text_content = arabic_reshaper.reshape(text_content)
text_content = get_display(text_content)

# %%
wordcloud = WordCloud(width=600, height=500, font_path='BHoma.ttf', background_color='White').generate(text_content)

# %%
import matplotlib.pyplot as plt
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 599.5, 499.5, -0.5)

# %%
wordcloud.to_file('SM_Chat.png')

# %%
from pathlib import Path

# %%
testdir = Path('cwd').resolve().parent

# %%
testdir
# Out:
# PosixPath('/mnt/d/python Programs/telegram_statistic/src/chat_statistics')

# %%
str('ali')
# Out:
# 'ali'
